# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

data = pd.read_csv('data/data_small.csv')

# %%
data.head(2)
# Out:
#     Unnamed: 0  label  month  day    year  body_len  code_to_body  num_tags  \
# 0            0      4    4.0  3.0  2012.0      1276      0.462264         1
# 1            1      1    1.0  3.0  2012.0       352      0.000000         4
# 2            2      0    5.0  2.0  2011.0       500      0.000000         1
# 3            3      0    4.0  0.0  2012.0       371      0.000000         3
# 4            4      0    1.0  6.0  2012.0       169      0.250000         2
# 5            5      2    8.0  2.0  2012.0       452      0.000000         3
# 6            6      0   10.0  0.0  2012.0       465      0.000000         2
# 7            7      2   12.0  3.0  2011.0       226      0.000000         3
# 8            8      0    5.0  4.0  2012.0       397      0.000000         2
# 9            9      0    8.0  1.0  2012.0       988      0.085366         4
# 10          10      0    8.0  0.0  2012.0       404      0.583333         4
# ...

# %%
data = data.drop('Unnamed: 0', 1)
data.head(2)
# Out:
#    label  month  day    year  body_len  code_to_body  num_tags  \
# 0      4    4.0  3.0  2012.0      1276      0.462264         1
# 1      1    1.0  3.0  2012.0       352      0.000000         4
# 2      0    5.0  2.0  2011.0       500      0.000000         1
# 3      0    4.0  0.0  2012.0       371      0.000000         3
# 4      0    1.0  6.0  2012.0       169      0.250000         2
#
#    num_code_blocks  code_exists  owner_undeleted_questions  owner_reputation  \
# 0                1            1                          0                 1
# 1                0            0                          0                 1
# 2                0            0                          2                40
# 3                0            0                          1                 1
# 4                1            1                          0                28
#
#           age  hw_in_tags  hw_in_title  hw_in_body
# 0   6659479.0           0            0           0
# ...

# %%
def set_binary(row):
    if row == 0:
        return 0
    else :
        return 1

# %%
Y_train=data['label'].apply(set_binary)
Y_train.head(2)
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
X_train_selected=data[['num_tags','body_len','owner_reputation','age']]
X_train_selected.head(2)
# Out:
#    num_tags  body_len  owner_reputation         age
# 0         1      1276                 1   6659479.0
# 1         4       352                 1       413.0
# 2         1       500                40   2948660.0
# 3         3       371                 1  45631059.0
# 4         2       169                28   7494233.0

# %%
# plotting a scatter matrix
from matplotlib import cm

cmap = cm.get_cmap('gnuplot')
scatter = pd.scatter_matrix(X_train_selected, c= Y_train, marker = 'o', s=40, hist_kwds={'bins':15}, figsize=(6,6), cmap=cmap)
# Out:
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
# <img src="data:image/png;base64,..." width="600">

# %%
X_train_selected=data[['hw_in_title','hw_in_tags','hw_in_body']]
X_train_selected.head(2)
# Out:
#    hw_in_title  hw_in_tags  hw_in_body
# 0            0           0           0
# 1            0           0           0
# 2            0           0           0
# 3            0           0           0
# 4            0           0           0

# %%
cmap = cm.get_cmap('gnuplot')
scatter = pd.scatter_matrix(X_train_selected, c= Y_train, marker = 'o', s=40, hist_kwds={'bins':15}, figsize=(6,6), cmap=cmap)
# Out:
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   from ipykernel import kernelapp as app
# <img src="data:image/png;base64,..." width="600">

# %%
X_train_selected=data[['body_len','owner_reputation','age']]
X_train_selected.head(2)
# Out:
#    body_len  owner_reputation         age
# 0      1276                 1   6659479.0
# 1       352                 1       413.0
# 2       500                40   2948660.0
# 3       371                 1  45631059.0
# 4       169                28   7494233.0

# %%
cmap = cm.get_cmap('gnuplot')
scatter = pd.scatter_matrix(X_train_selected, c= Y_train, marker = 'o', s=40, hist_kwds={'bins':15}, figsize=(6,6), cmap=cmap)
# Out:
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   from ipykernel import kernelapp as app
# <img src="data:image/png;base64,..." width="600">

# %%
# plotting a 3D scatter plot
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(data['body_len'], data['owner_reputation'], data['owner_undeleted_questions'], c = Y_train, marker = 'o', s=100)
ax.set_xlabel('body_len')
ax.set_ylabel('owner_reputation')
ax.set_zlabel('code_to_body')
ax.set_title('Features')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
